# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
elections_data = pd.read_html("https://en.wikipedia.org/wiki/2023_Nigerian_presidential_election", match="Nigeria 2023 Election Results by State")

# %%
elections_frame = pd.DataFrame(elections_data[0])

# %%
elections_frame.head(2)
# Out:
#                 State Bola TinubuAPC            Peter ObiLP             \
#                 State          Votes Percentage       Votes Percentage
# 0     Abia State[640]           8914      2.41%      327095     88.40%
# 1  Adamawa State[641]         182881     25.01%      105648     14.45%
#
#   Rabiu KwankwasoNNPP            Atiku AbubakarPDP            Others  \
#                 Votes Percentage             Votes Percentage  Votes
# 0                1239      0.33%             22676      6.13%  10113
# 1                8006      1.10%            417611     57.12%  16994
#
#              TotalValid Votes TurnoutPercentage
#   Percentage TotalValid Votes TurnoutPercentage
# 0      2.73%           370037            18.00%
# 1      2.32%           731140            34.67%

# %%
elections_frame.columns
# Out:
# MultiIndex([(              'State',             'State'),
#             (     'Bola TinubuAPC',             'Votes'),
#             (     'Bola TinubuAPC',        'Percentage'),
#             (        'Peter ObiLP',             'Votes'),
#             (        'Peter ObiLP',        'Percentage'),
#             ('Rabiu KwankwasoNNPP',             'Votes'),
#             ('Rabiu KwankwasoNNPP',        'Percentage'),
#             (  'Atiku AbubakarPDP',             'Votes'),
#             (  'Atiku AbubakarPDP',        'Percentage'),
#             (             'Others',             'Votes'),
#             (             'Others',        'Percentage'),
#             (   'TotalValid Votes',  'TotalValid Votes'),
#             (  'TurnoutPercentage', 'TurnoutPercentage')],
#            )

# %%
elections_frame.describe().T
# Out:
#                                       count          mean           std  \
# Bola TinubuAPC      Votes              38.0  4.631617e+05  1.395924e+06
# Peter ObiLP         Votes              38.0  3.208566e+05  9.777360e+05
# Rabiu KwankwasoNNPP Votes              38.0  7.877258e+04  2.861140e+05
# Atiku AbubakarPDP   Votes              38.0  3.674950e+05  1.110933e+06
# Others              Votes              38.0  3.425805e+04  1.033969e+05
# TotalValid Votes    TotalValid Votes   38.0  1.264596e+06  3.804812e+06
#
#                                            min        25%       50%  \
# Bola TinubuAPC      Votes               4772.0  137491.50  244419.5
# Peter ObiLP         Votes               1660.0   26463.25  102379.0
# Rabiu KwankwasoNNPP Votes                264.0    1697.75    4377.5
# Atiku AbubakarPDP   Votes               9036.0   89561.75  154346.5
# Others              Votes               3420.0    9312.75   12778.5
# TotalValid Votes    TotalValid Votes  165325.0  461375.00  557305.5
#
#                                             75%         max
# Bola TinubuAPC      Votes             343347.25   8794726.0
# Peter ObiLP         Votes             304902.50   6101533.0
# Rabiu KwankwasoNNPP Votes              12166.25   1496687.0
# Atiku AbubakarPDP   Votes             285105.75   6984520.0
# Others              Votes              19973.75    648474.0
# TotalValid Votes    TotalValid Votes  776519.75  24025940.0

# %%
elections_frame.drop(index=37, inplace=True)

# %%
elections_frame
# Out:
#                              State Bola TinubuAPC            Peter ObiLP  \
#                              State          Votes Percentage       Votes
# 0                  Abia State[640]           8914      2.41%      327095
# 1               Adamawa State[641]         182881     25.01%      105648
# 2   Akwa Ibom State[642][643][644]         160620     28.94%      132683
# 3               Anambra State[645]           5111      0.83%      584621
# 4                Bauchi State[646]         316694     37.10%       27373
# 5          Bayelsa State[647][648]          42572     25.75%       49975
# 6                 Benue State[649]         310468     40.32%      308372
# 7                 Borno State[650]         252282     54.22%        7205
# 8           Cross River State[651]         130520     31.30%      179917
# 9                 Delta State[652]          90183     14.66%      341866
# 10               Ebonyi State[653]          42402     13.03%      259738
# 11                  Edo State[654]         144471     24.86%      331163
# 12                Ekiti State[655]         201494     65.38%       11397
# 13           Enugu State[656][657]           4772      1.05%      428640
# 14  Federal Capital Territory[658]          90902     19.76%      281717
# 15                Gombe State[659]         146977     28.82%       26160
# 16                  Imo State[660]          66171     14.41%      352904
# 17          Jigawa State[661][662]         421390     45.78%        1889
# 18               Kaduna State[663]         399293     29.36%      294494
# 19                 Kano State[664]         517341     30.40%       28513
# 20              Katsina State[665]         482283     45.56%        6376
# 21                Kebbi State[666]         248088     44.34%       10682
# 22                 Kogi State[667]         240751     52.70%       56217
# 23           Kwara State[668][669]         263572     56.08%       31186
# 24                Lagos State[670]         572606     45.04%      582454
# 25             Nasarawa State[671]         172922     31.99%      191361
# 26                Niger State[672]         375183     48.18%       80452
# 27                 Ogun State[673]         341554     58.88%       85829
# 28                 Ondo State[674]         369924     67.14%       44405
# 29                 Osun State[675]         343945     46.91%       23283
# 30                  Oyo State[676]         449884     55.58%       99110
# 31              Plateau State[677]         307195     28.23%      466272
# 32               Rivers State[678]         231591     44.23%      175071
# 33               Sokoto State[679]         285444     48.64%        6568
# 34               Taraba State[680]         135165     27.07%      146315
# 35            Yobe State[681][682]         151459     40.03%        2406
# 36              Zamfara State[683]         298396     59.33%        1660
#
#               Rabiu KwankwasoNNPP            Atiku AbubakarPDP             \
#    Percentage               Votes Percentage             Votes Percentage
# 0      88.40%                1239      0.33%             22676      6.13%
# 1      14.45%                8006      1.10%            417611     57.12%
# 2      23.90%                7796      1.41%            214012     38.55%
# 3      95.24%                1967      0.32%              9036      1.47%
# 4       3.21%               72103      8.45%            426607     49.98%
# 5      30.23%                 540      0.33%             68818     41.62%
# 6      40.04%                4740      0.62%            130081     16.89%
# 7       1.55%                4626      0.99%            190921     41.03%
# 8      43.15%                1644      0.39%             95425     22.89%
# 9      55.55%                3122      0.51%            161600     26.26%
# 10     79.83%                1661      0.51%             13503      4.15%
# 11     56.97%                2743      0.47%             89585     15.41%
# 12      3.70%                 264      0.09%             89554     29.06%
# 13     93.91%                1808      0.40%             15749      3.45%
# 14     61.23%                4517      0.98%             74194     16.13%
# 15      5.13%               10520      2.06%            317123     62.17%
# 16     76.84%                1536      0.33%             30004      6.53%
# 17      0.20%               98234     10.67%            386587     42.00%
# 18     21.65%               92969      6.83%            554360     40.76%
# 19      1.67%              997279     58.59%            131716      7.74%
# 20      0.60%               69386      6.56%            489045     46.19%
# 21      1.91%                5038      0.90%            285175     50.97%
# 22     12.31%                4238      0.93%            145104     31.77%
# 23      6.63%                3141      0.67%            136909     29.13%
# 24     45.81%                8442      0.66%             75750      5.96%
# 25     35.40%               12715      2.35%            147093     27.21%
# 26     10.33%               21836      2.81%            284898     36.59%
# 27     14.79%                2200      0.38%            123831     21.35%
# 28      8.06%                 930      0.17%            115463     20.95%
# 29      3.17%                 713      0.10%            354366     48.33%
# 30     12.24%                4095      0.51%            182977     22.60%
# 31     42.85%                8869      0.81%            243808     22.41%
# 32     33.43%                1322      0.25%             88468     16.90%
# 33      1.12%                1300      0.22%            288679     49.19%
# 34     29.30%               12818      2.57%            189017     37.85%
# 35      0.64%               18270      4.83%            196567     52.47%
# 36      0.33%                4044      0.81%            193978     38.57%
#
#    Others            TotalValid Votes TurnoutPercentage
#     Votes Percentage TotalValid Votes TurnoutPercentage
# 0   10113      2.73%           370037            18.00%
# 1   16994      2.32%           731140            34.67%
# 2   39978      7.20%           555089            24.92%
# 3   13126      2.14%           613861            24.63%
# 4   10739      1.26%           853516            31.10%
# 5    3420      2.07%           165325            16.38%
# 6   16414      2.13%           770075            28.72%
# 7   10253      2.20%           465287            19.94%
# 8    9462      2.27%           416968            26.10%
# 9   18570      3.02%           615341            20.32%
# 10   8047      2.48%           325351            21.58%
# 11  13304      2.29%           581266            24.01%
# 12   5462      1.77%           308171            31.84%
# 13   5455      1.20%           456424            22.19%
# 14   8741      1.90%           460071            30.48%
# 15   9263      1.82%           510043            33.87%
# 16   8646      1.88%           459261            22.10%
# 17  12431      1.35%           920531            40.78%
# 18  19037      1.40%          1360153            32.33%
# 19  27156       1.6%          1702005            30.15%
# 20  11583      1.09%          1058673            31.03%
# 21  10539      1.88%           559522            29.81%
# 22  10480      2.29%           456790            24.63%
# 23  35203      7.49%           469971            29.29%
# 24  32199      2.53%          1271451            18.92%
# 25  16475      3.05%           540566            21.82%
# 26  16299      2.09%           778668            30.49%
# 27  26710      4.60%           580124            22.75%
# 28  20286      3.68%           551008            28.62%
# 29  10896      1.49%           733203            38.71%
# 30  73419      9.07%           809485            26.32%
# 31  62026      5.70%          1088170            40.33%
# 32  27199      5.19%           523651            16.71%
# 33   4824      0.82%           586815            29.84%
# 34  16043      3.21%           499358            26.67%
# 35   7695      2.03%           378397            26.75%
# 36   4845      0.96%           502923            27.64%

# %%
elections_frame.describe().T
# Out:
#                                       count           mean            std  \
# Bola TinubuAPC      Votes              37.0  237984.324324  149753.349775
# Peter ObiLP         Votes              37.0  164622.081081  170899.607971
# Rabiu KwankwasoNNPP Votes              37.0   40450.567568  163643.162889
# Atiku AbubakarPDP   Votes              37.0  188656.486486  139039.572838
# Others              Votes              37.0   17657.621622   15006.000080
# TotalValid Votes    TotalValid Votes   37.0  649424.054054  314160.798981
#
#                                            min       25%       50%       75%  \
# Bola TinubuAPC      Votes               4772.0  135165.0  240751.0  341554.0
# Peter ObiLP         Votes               1660.0   26160.0   99110.0  294494.0
# Rabiu KwankwasoNNPP Votes                264.0    1661.0    4238.0   10520.0
# Atiku AbubakarPDP   Votes               9036.0   89554.0  147093.0  284898.0
# Others              Votes               3420.0    9263.0   12431.0   19037.0
# TotalValid Votes    TotalValid Votes  165325.0  460071.0  555089.0  770075.0
#
#                                             max
# Bola TinubuAPC      Votes              572606.0
# Peter ObiLP         Votes              584621.0
# Rabiu KwankwasoNNPP Votes              997279.0
# Atiku AbubakarPDP   Votes              554360.0
# Others              Votes               73419.0
# TotalValid Votes    TotalValid Votes  1702005.0

# %%
# States where each candidate got the most amount of votes

apc_most_votes = elections_frame.loc[:, ("Bola TinubuAPC", "Votes")] == elections_frame.loc[:, ("Bola TinubuAPC", "Votes")].max()

# %%
elections_frame[apc_most_votes]
# Out:
#                State Bola TinubuAPC            Peter ObiLP             \
#                State          Votes Percentage       Votes Percentage
# 24  Lagos State[670]         572606     45.04%      582454     45.81%
#
#    Rabiu KwankwasoNNPP            Atiku AbubakarPDP            Others  \
#                  Votes Percentage             Votes Percentage  Votes
# 24                8442      0.66%             75750      5.96%  32199
#
#               TotalValid Votes TurnoutPercentage
#    Percentage TotalValid Votes TurnoutPercentage
# 24      2.53%          1271451            18.92%

# %%
labour_most_votes = elections_frame.loc[:, ("Peter ObiLP", "Votes")] == elections_frame.loc[:, ("Peter ObiLP", "Votes")].max()

# %%
elections_frame[labour_most_votes]
# Out:
#                 State Bola TinubuAPC            Peter ObiLP             \
#                 State          Votes Percentage       Votes Percentage
# 3  Anambra State[645]           5111      0.83%      584621     95.24%
#
#   Rabiu KwankwasoNNPP            Atiku AbubakarPDP            Others  \
#                 Votes Percentage             Votes Percentage  Votes
# 3                1967      0.32%              9036      1.47%  13126
#
#              TotalValid Votes TurnoutPercentage
#   Percentage TotalValid Votes TurnoutPercentage
# 3      2.14%           613861            24.63%

# %%
pdp_most_votes = elections_frame.loc[:, ("Atiku AbubakarPDP", "Votes")] == elections_frame.loc[:, ("Atiku AbubakarPDP", "Votes")].max()

# %%
elections_frame[pdp_most_votes]
# Out:
#                 State Bola TinubuAPC            Peter ObiLP             \
#                 State          Votes Percentage       Votes Percentage
# 18  Kaduna State[663]         399293     29.36%      294494     21.65%
#
#    Rabiu KwankwasoNNPP            Atiku AbubakarPDP            Others  \
#                  Votes Percentage             Votes Percentage  Votes
# 18               92969      6.83%            554360     40.76%  19037
#
#               TotalValid Votes TurnoutPercentage
#    Percentage TotalValid Votes TurnoutPercentage
# 18      1.40%          1360153            32.33%

# %%
nnpp_most_votes = elections_frame.loc[:, ("Rabiu KwankwasoNNPP", "Votes")] == elections_frame.loc[:, ("Rabiu KwankwasoNNPP", "Votes")].max()

# %%
elections_frame[pdp_most_votes]
# Out:
#                 State Bola TinubuAPC            Peter ObiLP             \
#                 State          Votes Percentage       Votes Percentage
# 18  Kaduna State[663]         399293     29.36%      294494     21.65%
#
#    Rabiu KwankwasoNNPP            Atiku AbubakarPDP            Others  \
#                  Votes Percentage             Votes Percentage  Votes
# 18               92969      6.83%            554360     40.76%  19037
#
#               TotalValid Votes TurnoutPercentage
#    Percentage TotalValid Votes TurnoutPercentage
# 18      1.40%          1360153            32.33%

# %%
labour_turnout_most = elections_frame[labour_most_votes].loc[:, ("TurnoutPercentage", "TurnoutPercentage")]

# %%
labour_turnout_most
# Out:
# 3    24.63%
# Name: (TurnoutPercentage, TurnoutPercentage), dtype: object

# %%
elections_frame.loc[:, ("TurnoutPercentage", "TurnoutPercentage")].describe()
# Out:
# count         37
# unique        36
# top       24.63%
# freq           2
# Name: (TurnoutPercentage, TurnoutPercentage), dtype: object

# %%
elections_frame.loc[:, ("TurnoutPercentage", "TurnoutPercentage")].max()
# Out:
# '40.78%'

# %%
politically_active = elections_frame.loc[:, [("State", "State"), ("TurnoutPercentage", "TurnoutPercentage")]]

# %%
politically_active
# Out:
#                              State TurnoutPercentage
#                              State TurnoutPercentage
# 0                  Abia State[640]            18.00%
# 1               Adamawa State[641]            34.67%
# 2   Akwa Ibom State[642][643][644]            24.92%
# 3               Anambra State[645]            24.63%
# 4                Bauchi State[646]            31.10%
# 5          Bayelsa State[647][648]            16.38%
# 6                 Benue State[649]            28.72%
# 7                 Borno State[650]            19.94%
# 8           Cross River State[651]            26.10%
# 9                 Delta State[652]            20.32%
# 10               Ebonyi State[653]            21.58%
# 11                  Edo State[654]            24.01%
# 12                Ekiti State[655]            31.84%
# 13           Enugu State[656][657]            22.19%
# 14  Federal Capital Territory[658]            30.48%
# 15                Gombe State[659]            33.87%
# 16                  Imo State[660]            22.10%
# 17          Jigawa State[661][662]            40.78%
# 18               Kaduna State[663]            32.33%
# 19                 Kano State[664]            30.15%
# 20              Katsina State[665]            31.03%
# 21                Kebbi State[666]            29.81%
# 22                 Kogi State[667]            24.63%
# 23           Kwara State[668][669]            29.29%
# 24                Lagos State[670]            18.92%
# 25             Nasarawa State[671]            21.82%
# 26                Niger State[672]            30.49%
# 27                 Ogun State[673]            22.75%
# 28                 Ondo State[674]            28.62%
# 29                 Osun State[675]            38.71%
# 30                  Oyo State[676]            26.32%
# 31              Plateau State[677]            40.33%
# 32               Rivers State[678]            16.71%
# 33               Sokoto State[679]            29.84%
# 34               Taraba State[680]            26.67%
# 35            Yobe State[681][682]            26.75%
# 36              Zamfara State[683]            27.64%

# %%
most_turnout = politically_active.loc[:, ("TurnoutPercentage", "TurnoutPercentage")].max()

# %%
most_politically_active = politically_active.loc[:, ("TurnoutPercentage", "TurnoutPercentage")] == most_turnout

# %%
politically_active[most_politically_active][("State", "State")]
# Out:
# 17    Jigawa State[661][662]
# Name: (State, State), dtype: object

# %%
least_turnout = politically_active.loc[:, ("TurnoutPercentage", "TurnoutPercentage")].min()

# %%
least_politically_active = politically_active.loc[:, ("TurnoutPercentage", "TurnoutPercentage")] == least_turnout

# %%
politically_active[least_politically_active][("State", "State")]
# Out:
# 5    Bayelsa State[647][648]
# Name: (State, State), dtype: object
